# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Loading Datasets
dataset=pd.read_csv("dataset.csv")
description=pd.read_csv("symptom_Description.csv")
precaution=pd.read_csv("symptom_precaution.csv")
severity=pd.read_csv("Symptom-severity.csv")

# %%
dataset
# Out:
#                                       Disease             Symptom_1  \
# 0                            Fungal infection               itching
# 1                            Fungal infection             skin_rash
# 2                            Fungal infection               itching
# 3                            Fungal infection               itching
# 4                            Fungal infection               itching
# ...                                       ...                   ...
# 4915  (vertigo) Paroymsal  Positional Vertigo              vomiting
# 4916                                     Acne             skin_rash
# 4917                  Urinary tract infection   burning_micturition
# 4918                                Psoriasis             skin_rash
# 4919                                 Impetigo             skin_rash
#
#                   Symptom_2              Symptom_3                  Symptom_4  \
# ...

# %%
description
# Out:
#                                     Disease  \
# 0                             Drug Reaction
# 1                                   Malaria
# 2                                   Allergy
# 3                            Hypothyroidism
# 4                                 Psoriasis
# 5                                      GERD
# 6                       Chronic cholestasis
# 7                               hepatitis A
# 8                           Osteoarthristis
# 9   (vertigo) Paroymsal  Positional Vertigo
# 10                             Hypoglycemia
# 11                                     Acne
# 12                                 Diabetes
# 13                                 Impetigo
# 14                             Hypertension
# 15                      Peptic ulcer diseae
# 16             Dimorphic hemorrhoids(piles)
# 17                              Common Cold
# 18                              Chicken pox
# 19                     Cervical spondylosis
# ...

# %%
precaution
# Out:
#                                     Disease  \
# 0                             Drug Reaction
# 1                                   Malaria
# 2                                   Allergy
# 3                            Hypothyroidism
# 4                                 Psoriasis
# 5                                      GERD
# 6                       Chronic cholestasis
# 7                               hepatitis A
# 8                           Osteoarthristis
# 9   (vertigo) Paroymsal  Positional Vertigo
# 10                             Hypoglycemia
# 11                                     Acne
# 12                                Diabetes
# 13                                 Impetigo
# 14                            Hypertension
# 15                      Peptic ulcer diseae
# 16             Dimorphic hemmorhoids(piles)
# 17                              Common Cold
# 18                              Chicken pox
# 19                     Cervical spondylosis
# ...

# %%
severity
# Out:
#                   Symptom  weight
# 0                 itching       1
# 1               skin_rash       3
# 2    nodal_skin_eruptions       4
# 3     continuous_sneezing       4
# 4               shivering       5
# ..                    ...     ...
# 128    inflammatory_nails       2
# 129               blister       4
# 130  red_sore_around_nose       2
# 131     yellow_crust_ooze       3
# 132             prognosis       5
#
# [133 rows x 2 columns]

# %%
print("Null value in dataset:\n",dataset.isnull().count())
print()
print()
print("Null value in description:\n",descriptiont.isnull().count())
print()
print()
print("Null value in severity:\n",severity.isnull().count())
print()
print()
print("Null value in precaution:\n",precaution.isnull().count())
# Out:
# Null value in dataset:
#  Disease       4920
# Symptom_1     4920
# Symptom_2     4920
# Symptom_3     4920
# Symptom_4     4920
# Symptom_5     4920
# Symptom_6     4920
# Symptom_7     4920
# Symptom_8     4920
# Symptom_9     4920
# Symptom_10    4920
# Symptom_11    4920
# Symptom_12    4920
# Symptom_13    4920
# Symptom_14    4920
# Symptom_15    4920
# Symptom_16    4920
# Symptom_17    4920
# dtype: int64
#
#
# Null value in description:
#  Disease        41
# Description    41
# dtype: int64
#
#
# Null value in severity:
#  Symptom    133
# weight     133
# dtype: int64
#
#
# Null value in precaution:
#  Disease         41
# Precaution_1    41
# Precaution_2    41
# Precaution_3    41
# Precaution_4    41
# dtype: int64

# %%
# Missing values summary
print(f"Main dataset shape: {dataset.shape}")
print(f"Symptom Severity shape: {severity.shape}")
print(f"Symptom Description shape: {description.shape}")
print(f"Symptom Precaution shape: {precaution.shape}")
# Out:
# Main dataset shape: (4920, 18)
# Symptom Severity shape: (133, 2)
# Symptom Description shape: (41, 2)
# Symptom Precaution shape: (41, 5)

# %%
#  Missing values summary

# %%
missing_perc = dataset.isnull().mean() * 100
missing_perc = missing_perc.drop('Disease')

# %%
print("\nPercentage of Missing Values Per Symptom Column:")
print(missing_perc)
# Out:
# Percentage of Missing Values Per Symptom Column:
# Symptom_1      0.000000
# Symptom_2      0.000000
# Symptom_3      0.000000
# Symptom_4      7.073171
# Symptom_5     24.512195
# Symptom_6     40.365854
# Symptom_7     53.902439
# Symptom_8     60.487805
# Symptom_9     65.609756
# Symptom_10    69.268293
# Symptom_11    75.731707
# Symptom_12    84.878049
# Symptom_13    89.756098
# Symptom_14    93.780488
# Symptom_15    95.121951
# Symptom_16    96.097561
# Symptom_17    98.536585
# dtype: float64

# %%
# Bar Plotting 
missing_perc.plot(kind='bar', color='coral')
plt.title('Percentage of Missing Values per Symptom Column',fontsize=20,color='r')
plt.ylabel('Percentage (%)',color='g',fontsize=14)
plt.xlabel('Symptom Columns',color='g',fontsize=14)
plt.xticks(rotation=45)
plt.grid("True",linestyle='--')
plt.show()

# %%
# Class distribution
disease_counts = dataset['Disease'].value_counts()

print("\nNumber of samples per disease (top 10):")
print(disease_counts.head(10))

sns.barplot(y=disease_counts.index[:10], x=disease_counts.values[:10], palette='viridis')
plt.title('Top 10 Disease Sample Counts')
plt.xlabel('Number of Samples')
plt.ylabel('Disease')
plt.show()
# Out:
# Number of samples per disease (top 10):
# Disease
# Fungal infection       120
# Allergy                120
# GERD                   120
# Chronic cholestasis    120
# Drug Reaction          120
# Peptic ulcer diseae    120
# AIDS                   120
# Diabetes               120
# Gastroenteritis        120
# Bronchial Asthma       120
# Name: count, dtype: int64
# C:\Users\kumad\AppData\Local\Temp\ipykernel_21000\2028142677.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=disease_counts.index[:10], x=disease_counts.values[:10], palette='viridis')

# %%
# Unique symptom counts by column

symptom_cols = [col for col in dataset.columns if col.startswith('Symptom_')]
unique_counts = dataset[symptom_cols].nunique()

print("\nNumber of unique symptom labels per symptom column:")
print(unique_counts)
# Out:
# Number of unique symptom labels per symptom column:
# Symptom_1     34
# Symptom_2     48
# Symptom_3     54
# Symptom_4     50
# Symptom_5     38
# Symptom_6     32
# Symptom_7     26
# Symptom_8     21
# Symptom_9     22
# Symptom_10    21
# Symptom_11    18
# Symptom_12    11
# Symptom_13     8
# Symptom_14     4
# Symptom_15     3
# Symptom_16     3
# Symptom_17     1
# dtype: int64

# %%
unique_counts.plot(kind='bar', color='seagreen')
plt.title('Unique Symptom Labels per Symptom Column')
plt.ylabel('Number of Unique Symptoms')
plt.xlabel('Symptom Columns')
plt.xticks(rotation=45)
plt.show()

# %%
# Some symptom severity data distribution

print("\nSymptom Severity Sample:")
print(severity)
# Out:
# Symptom Severity Sample:
#                   Symptom  weight
# 0                 itching       1
# 1               skin_rash       3
# 2    nodal_skin_eruptions       4
# 3     continuous_sneezing       4
# 4               shivering       5
# ..                    ...     ...
# 128    inflammatory_nails       2
# 129               blister       4
# 130  red_sore_around_nose       2
# 131     yellow_crust_ooze       3
# 132             prognosis       5
#
# [133 rows x 2 columns]

# %%
# Create histogram with bins from 0 to 8 (to cover 0-7 inclusive)

import matplotlib.pyplot as plt

weights=severity['weight']

bins = range(0, 9)
counts, bins_, patches = plt.hist(weights, bins=bins, edgecolor='black', color='orange')

plt.title('Distribution of Symptom Severity Weights (0-7)')
plt.xlabel('Severity Weight')
plt.ylabel('Frequency')
plt.xticks(range(0, 8))  # Show ticks for each integer severity weight

# Add counts on top of bars
for count, patch in zip(counts, patches):
    if count > 0:
        plt.text(patch.get_x() + patch.get_width() / 2, count + 0.5,  # position above the bar
                 int(count), ha='center', va='bottom', fontsize=10)
plt

plt.show()
